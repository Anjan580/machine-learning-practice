# %%
import nltk

# %%
from nltk import word_tokenize

# %%
text = 'Data science is the field of applying advanced analytics techniques and scientific principles to extract valuable information from data for 	business decisionmaking strategic planning and other uses'

# %%
token = word_tokenize(text)
print(token)
# Out:
# ['Data', 'science', 'is', 'the', 'field', 'of', 'applying', 'advanced', 'analytics', 'techniques', 'and', 'scientific', 'principles', 'to', 'extract', 'valuable', 'information', 'from', 'data', 'for', 'business', 'decisionmaking', 'strategic', 'planning', 'and', 'other', 'uses']

# %%
# pos tagging
tags = nltk.pos_tag(tokens)
print(tags)
# Out:
# [('Data', 'NNP'), ('science', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('field', 'NN'), ('of', 'IN'), ('applying', 'VBG'), ('advanced', 'JJ'), ('analytics', 'NNS'), ('techniques', 'NNS'), ('and', 'CC'), ('scientific', 'JJ'), ('principles', 'NNS'), ('to', 'TO'), ('extract', 'VB'), ('valuable', 'JJ'), ('information', 'NN'), ('from', 'IN'), ('data', 'NN'), ('for', 'IN'), ('business', 'NN'), ('decisionmaking', 'VBG'), ('strategic', 'JJ'), ('planning', 'NN'), ('and', 'CC'), ('other', 'JJ'), ('uses', 'NNS')]

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk.help import upenn_tagset

# %%
upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping help\tagsets_json.zip.
# True

# %% [markdown]
# # text classification

# %%
data = {
    'text': [
        'I love this product', 
        'Worst service ever', 
        'Absolutely fantastic!', 
        'Very bad',
        'Horrible experience', 
        'Very helpful staff'
    ],
    'label': ['positive', 'negative', 'positive', 'negative', 'negative', 'positive']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#                     text     label
# 0    I love this product  positive
# 1     Worst service ever  negative
# 2  Absolutely fantastic!  positive
# 3               Very bad  negative
# 4    Horrible experience  negative
# 5     Very helpful staff  positive

# %%
X = df[['text']]
y = df.label

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import classification_report, accuracy_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
vectorizer = TfidfVectorizer()
x_vector = vectorizer.fit_transform(df['text'])

# %% [markdown]
# ![image.png](attachment:9df8b9ac-8a47-487d-babf-3bc024e5bc5e.png)

# %%
# xtrain, xtest, ytrain, ytest = train

# %%
text_model = LogisticRegression()
text_model.fit(x_vector,y)
# Out:
# LogisticRegression()

# %% [markdown]
# ### to be continue
