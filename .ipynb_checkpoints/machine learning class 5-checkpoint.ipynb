# %% [markdown]
# # Correlation, Encoding

# %%
# 1. correlation 
Linear Regression(SLR, MLR)
Logistic Regression

# %%
# 1. Assumptions
Linear Relationship
no multicolinearity

# %%
import pandas as pd

# %%
data = pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.dropna(inplace = True)

# %%
1. Linear Relationship
(Independent, dependent)
i. scatterplot
ii. correlation

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.Age, data.Salary)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
correlation = data['Age'].corr(data['Salary'])
correlation
# Out:
# np.float64(0.7280606296367429)

# %%
# no multicolinr=earity
Among indepdent variable , correlation sholuld low

# %%
data['Age'].corr(['Years of Experience'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20508\4105039082.py in ?()
# ----> 1 data['Age'].corr(['Years of Experience'])
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\series.py in ?(self, other, method, min_periods)
#    2965         >>> s2 = pd.Series([1, 2, 3], index=[2, 1, 0])
#    2966         >>> s1.corr(s2)
#    2967         -1.0
#    2968         """  # noqa: E501
# -> 2969         this, other = self.align(other, join="inner", copy=False)
#    2970         if len(this) == 0:
#    2971             return np.nan
#    2972
#
# ...

# %%
df = pd.read_csv('Diabetes(in).csv')
df.head()
# Out:
#    Pragnency  Glucose  Blod Pressure  Skin Thikness  Insulin   BMI    DFP  \
# 0          1       85             66             29        0  26.6  0.351
# 1          8      183             64              0        0  23.3  0.672
# 2          1       89             66             23       94  28.1  0.167
# 3          0      137             40             35      168  43.1  2.288
# 4          5      116             74              0        0  25.6  0.201
#
#    Age  Diabetes
# 0   31         0
# 1   32         1
# 2   21         0
# 3   33         1
# 4   30         0

# %%
x = df[['Glucose', 'Blod Pressure', 'DFP', 'Age']]
x.head()
# Out:
#    Glucose  Blod Pressure    DFP  Age
# 0       85             66  0.351   31
# 1      183             64  0.672   32
# 2       89             66  0.167   21
# 3      137             40  2.288   33
# 4      116             74  0.201   30

# %%
cor = x.corr()

# %%
cor
# Out:
#                 Glucose  Blod Pressure       DFP       Age
# Glucose        1.000000       0.152498  0.136903  0.262408
# Blod Pressure  0.152498       1.000000  0.041180  0.239571
# DFP            0.136903       0.041180  1.000000  0.032738
# Age            0.262408       0.239571  0.032738  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(cor, annot = True)
plt.show()

# %% [markdown]
# # Encoding
#      conversion of categorical into numerical

# %% [markdown]
# Nominal
# Ordinal : label Encoding ==> HS(0)-BAchelors(1)- Masters(2)- Phd(3)

# %%
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.dropna(inplace = True)

# %%
data['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
# first make consistent
data['Education Level'] = data['Education Level'].replace({
    "Bachelor's": 'Bachelors',
    "Bachelor's Degree": 'Bachelors',
    "Master's": 'Masters',
    "Master's Degree": 'Masters',
    "phD": 'phD',
    "PhD": 'phD'
})

# %%
data['Education Level'].unique()
# Out:
# array(['Bachelors', 'Masters', 'phD', 'High School'], dtype=object)

# %%
# Encoding
data['Education Level'] = data['Education Level'].map({
    'High School':0,
    'Bachelors':1,
    'Masters':2,
    'phD':3
})

# %%
data.head()
# Out:
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0    Male                1  Software Engineer                  5.0
# 1  28.0  Female                2       Data Analyst                  3.0
# 2  45.0    Male                3     Senior Manager                 15.0
# 3  36.0  Female                1    Sales Associate                  7.0
# 4  52.0    Male                2           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
x  = data[['Age', 'Eduction Level','Years of Experience']]

# %%
# Encoding for Gender

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df = data

# %%
data = pd.get_dummies(data, columns = ['Gender'])
data.head()
# Out:
#     Age  Education Level          Job Title  Years of Experience    Salary  \
# 0  32.0                1  Software Engineer                  5.0   90000.0
# 1  28.0                2       Data Analyst                  3.0   65000.0
# 2  45.0                3     Senior Manager                 15.0  150000.0
# 3  36.0                1    Sales Associate                  7.0   60000.0
# 4  52.0                2           Director                 20.0  200000.0
#
#    Gender_Female  Gender_Male  Gender_Other
# 0          False         True         False
# 1           True        False         False
# 2          False         True         False
# 3           True        False         False
# 4          False         True         False

# %%
data = df

# %%
data.head()
# Out:
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0    Male                1  Software Engineer                  5.0
# 1  28.0  Female                2       Data Analyst                  3.0
# 2  45.0    Male                3     Senior Manager                 15.0
# 3  36.0  Female                1    Sales Associate                  7.0
# 4  52.0    Male                2           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data = pd.get_dummies(data, columns = ['Gender'], dtype = int, drop_first = True)
data.head()
# Out:
#     Age  Education Level          Job Title  Years of Experience    Salary  \
# 0  32.0                1  Software Engineer                  5.0   90000.0
# 1  28.0                2       Data Analyst                  3.0   65000.0
# 2  45.0                3     Senior Manager                 15.0  150000.0
# 3  36.0                1    Sales Associate                  7.0   60000.0
# 4  52.0                2           Director                 20.0  200000.0
#
#    Gender_Male  Gender_Other
# 0            1             0
# 1            0             0
# 2            1             0
# 3            0             0
# 4            1             0

# %%
data.head(15)
# Out:
#      Age  Education Level              Job Title  Years of Experience  \
# 0   32.0                1      Software Engineer                  5.0
# 1   28.0                2           Data Analyst                  3.0
# 2   45.0                3         Senior Manager                 15.0
# 3   36.0                1        Sales Associate                  7.0
# 4   52.0                2               Director                 20.0
# 5   29.0                1      Marketing Analyst                  2.0
# 6   42.0                2        Product Manager                 12.0
# 7   31.0                1          Sales Manager                  4.0
# 8   26.0                1  Marketing Coordinator                  1.0
# 9   38.0                3       Senior Scientist                 10.0
# 10  29.0                2     Software Developer                  3.0
# 11  48.0                1             HR Manager                 18.0
# ...

# %%
x = data[['Age', 'Education Level', 'Gender_Male', 'Gender_Other']]

# %%
y= df['Salary']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size= 0.2, random_state = 15)

# %%
log_model = LogisticRegression()
log_model.fit(xtrain, ytrain)
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict([[40, 1, 0, 0]])  # age = 40, Education level = Bachelors(1), female
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 model.predict([[40, 1, 0, 0]])
#
# NameError: name 'model' is not defined
