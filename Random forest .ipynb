# %% [markdown]
# # Random Forest

# %% [markdown]
# #### Create multiple Decision tree

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
df = pd.read_csv('Diabetes(in).csv')
df.head()
# Out:
#    Pragnency  Glucose  Blod Pressure  Skin Thikness  Insulin   BMI    DFP  \
# 0          1       85             66             29        0  26.6  0.351
# 1          8      183             64              0        0  23.3  0.672
# 2          1       89             66             23       94  28.1  0.167
# 3          0      137             40             35      168  43.1  2.288
# 4          5      116             74              0        0  25.6  0.201
#
#    Age  Diabetes
# 0   31         0
# 1   32         1
# 2   21         0
# 3   33         1
# 4   30         0

# %%
x = df[['Glucose' , 'Age']]
y = df.Diabetes

# %%
xtrain , xtest, ytrain, ytest = train_test_split(x ,y, test_size = 0.2, random_state = 12)

# %%
rfmodel = RandomForestClassifier(n_estimators = 200, max_depth = 6)
rfmodel.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=200)

# %%
# Evalution
yprediction = rfmodel.predict(xtest)

# %%
accuracy = accuracy_score(ytest, yprediction)
print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:74.68%

# %%
rfmodel.predict([[100,21]])
# Out:
# C:\Users\Dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plot_tree(rfmodel, filled = true)
plt.show()

# %%
plt.scatter(x.Glucose, x.Age, c = y)
plt.xlabel('Glucose')
plt.ylabel('Age')
plt.show()

# %%
sns.scatterplot(data = df, x = 'Glucose', y = 'Age', hue = 'Diabetes')
plt.show()
